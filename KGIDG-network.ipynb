# %% [markdown]
# <H1>KG-IDG dataset</H1>
# <p>The <a href="https://druggablegenome.net/">Illuminating Druggable Genome (IDG) Consortium</a> has the aim of highlighting current knowledge of protein targets through integration of informatics tools.</p>
# <p><a href="https://academic.oup.com/bioinformatics/article/39/7/btad418/7211646">KG-Hub</a> is a platform that enables standardized construction, exchange, and reuse of KGs.
# Here, we use the KG-Hub graph created with KG-HUB.</p>
# <p>This notebook demonstrates how the KG-IDG dataset is generated using GRAPE. We first extract the entire graph and
# then choose the largest connected component. Here, we are interested in predicting protein-drug interactions; we therefore
# focus on edges whose source node is one of "biolink:ChemicalSubstance", "biolink:ChemicalEntity", "biolink:Drug" (representing medications) and whose destination node is "biolink:Protein". We define the corresponding edge type as "minority_edge" (the name is arbitrary).</p>
# <p>The notebook then demonstrates the code used for training using SMOKE_TEST mode (the actual analysis was performed using the script TODO </p>

# %%
from grape.datasets.kghub import KGIDG
g = KGIDG(version='20230801') # see here for dashboard describing graph: http://kghub.org/kg-hub-dashboard/
g
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>KGIDG</h2><p class="paragraph">The undirected multigraph KGIDG has 556.19K heterogeneous nodes and 2.83M heterogeneous edges. The graph contains 58.37K connected components (of which 52.88K are disconnected nodes), with the largest one containing 465.57K nodes and the smallest one containing a single node. The RAM requirements for the nodes and edges data structures are 64.89MB and 27.09MB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 0, the maximum node degree is 9.36K, the mode degree is 1, the mean degree is 10.18 and the node degree median is 1.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='http://amigo.geneontology.org/amigo/term/GO:0065007' target='_blank' title='Go to Gene Ontology to get more informations about GO:0065007'>GO:0065007</a> (degree 9.36K and node types <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcess.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcess'>biolink:BiologicalProcess</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:24995' target='_blank' title='Go to CHEBI to get more informations about CHEBI:24995'>CHEBI:24995</a> (degree 7.35K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:52898' target='_blank' title='Go to CHEBI to get more informations about CHEBI:52898'>CHEBI:52898</a> (degree 7.26K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:16670' target='_blank' title='Go to CHEBI to get more informations about CHEBI:16670'>CHEBI:16670</a> (degree 6.39K and node types <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a> and <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:30616' target='_blank' title='Go to CHEBI to get more informations about CHEBI:30616'>CHEBI:30616</a> (degree 6.01K and node types <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations abo ...
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000143933' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000143933'>ENSEMBL:ENSG00000143933</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000131089' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000131089'>ENSEMBL:ENSG00000131089</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000178607' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000178607'>ENSEMBL:ENSG00000178607</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000147889' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000147889'>ENSEMBL:ENSG00000147889</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000185624' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000185624'>ENSEMBL:ENSG00000185624</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000104915' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000104915'>ENSEMBL:ENSG00000104915</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000114450' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000114450'>ENSEMBL:ENSG00000114450</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000168280' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000168280'>ENSEMBL:ENSG00000168280</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000159131' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000159131'>ENSEMBL:ENSG00000159131</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000211456' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000211456'>ENSEMBL:ENSG00000211456</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000100359' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000100359'>ENSEMBL:ENSG00000100359</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000120370' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000120370'>ENSEMBL:ENSG00000120370</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000113971' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000113971'>ENSEMBL:ENSG00000113971</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ensembl.org/Gene/Summary?g=ENSG00000196730' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSG00000196730'>ENSEMBL:ENSG00000196730</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li></ul><p class="paragraph">And other 52.83K singleton nodes.</p><h4 style="margin: 1em 0 0 0;">Singleton nodes with self-loops</h4><p class="paragraph">A singleton node with self-loops is a node disconnected from all other nodes except itself. We have detected 42 singleton nodes with self-loops in the graph, involving a total of 42 nodes and 49 edges. The detected singleton nodes with self-loops are:</p><ul class="small-columns"><li><p class="paragraph"><a href='http://identifiers.org/pombase/SPAC19B12.10' target='_blank' title='Go to POMBASE to get more informations about PomBase:SPAC19B12.10'>PomBase:SPAC19B12.10</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a>)</p></li>
# <li><p class="paragraph"><a href='https://wormbase.org/search/all/WBGene00021477' target='_blank' title='Go to WormBase Gene to get more informations about WormBase:WBGene00021477'>WormBase:WBGene00021477</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a>)</p></li>
# <li><p class="paragraph"><a href='http://www.informatics.jax.org/reference/strain/MGI:102463' target='_blank' title='Go to Mouse Genome Informatics to get more informations about MGI:102463'>MGI:102463</a> (degree 4 and node type <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a>)</p></li>
# <li><p class="paragraph"><a href='https://reactome.org/content/detail/R-HSA-1604613' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1604613'>REACT:R-HSA-1604613</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Pathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:Pathway'>biolink:Pathway</a>)</p></li>
# <li><p class="paragraph"><a href='http://www.informatics.jax.org/reference/strain/MGI:97548' target='_blank' title='Go to Mouse Genome Informatics to get more informations about MGI:97548'>MGI:97548</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a>)</p></li>
# <li><p class="paragraph"><a href='http://zfin.org/ZDB-GENE-020812-1' target='_blank' title='Go to ZFIN to get more informations about ZFIN:ZDB-GENE-020812-1'>ZFIN:ZDB-GENE-020812-1</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a>)</p></li>
# <li><p class="paragraph"><a href='https://reactome.org/content/detail/R-ALL-72617' target='_blank' title='Go to Reactome to get more informations about REACT:R-ALL-72617'>REACT:R-ALL-72617</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Pathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:Pathway'>biolink:Pathway</a>)</p></li>
# <li><p class="paragraph"><a href='https://reactome.org/content/detail/R-HSA-141050' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-141050'>REACT:R-HSA-141050</a> (degree 2 and node type <a href='https://biolink.github.io/biolink-model/docs/Pathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:Pathway'>biolink:Pathway</a>)</p></li>
# <li><p class="paragraph"><a href='https://reactome.org/content/detail/R-HSA-194019' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-194019'>REACT:R-HSA-194019</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Pathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:Pathway'>biolink:Pathway</a>)</p></li>
# <li><p class="paragraph"><a href='https://reactome.org/content/detail/R-HSA-72500' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-72500'>REACT:R-HSA-72500</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Pathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:Pathway'>biolink:Pathway</a>)</p></li>
# <li><p class="paragraph"><a href='http://www.informatics.jax.org/reference/strain/MGI:1933206' target='_blank' title='Go to Mouse Genome Informatics to get more informations about MGI:1933206'>MGI:1933206</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a>)</p></li>
# <li><p class="paragraph"><a href='https://reactome.org/content/detail/R-HSA-904821' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-904821'>REACT:R-HSA-904821</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Pathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:Pathway'>biolink:Pathway</a>)</p></li>
# <li><p class="paragraph"><a href='http://www.informatics.jax.org/reference/strain/MGI:1924846' target='_blank' title='Go to Mouse Genome Informatics to get more informations about MGI:1924846'>MGI:1924846</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a>)</p></li>
# <li><p class="paragraph"><a href='https://reactome.org/content/detail/R-HSA-1498783' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1498783'>REACT:R-HSA-1498783</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Pathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:Pathway'>biolink:Pathway</a>)</p></li>
# <li><p class="paragraph"><a href='https://reactome.org/content/detail/R-HSA-192115' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-192115'>REACT:R-HSA-192115</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Pathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:Pathway'>biolink:Pathway</a>)</p></li></ul><p class="paragraph">And other 27 singleton nodes with self-loops.</p><h4 style="margin: 1em 0 0 0;">Chains</h4><p class="paragraph">A chain is a path of nodes with unique degree 2, that is ignoring self-loop and multi-edges, connecting two strongly connected components of the graph. We have detected  a single chain in the graph, involving a total of 10 nodes and 9 edges, with the largest one involving 10 nodes and 9 edges.</p><ul class="medium-columns"><li><p class="paragraph">Chain containing 10 nodes and starts from the node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=70999' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:70999'>NCBITaxon:70999</a>. Specifically, the nodes involved in the chain are: <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=27479' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:27479'>NCBITaxon:27479</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33356' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33356'>NCBITaxon:33356</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33354' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33354'>NCBITaxon:33354</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33351' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33351'>NCBITaxon:33351</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33349' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33349'>NCBITaxon:33349</a> and other 4. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (19 edges, 95.00%) and <a href='https://biolink.github.io/biolink-model/docs/related_to.html' target='_blank' title='Go to BioLink to get more informations about biolink:related_to'>biolink:related_to</a>.</p></li></ul><h4 style="margin: 1em 0 0 0;">Node tuples</h4><p class="paragraph">A node tuple is a connected component composed of two nodes. We have detected 3.98K node tuples in the graph, involving a total of 7.96K nodes (1.43%) and 3.98K edges (0.07%). The detected node tuples are:</p><ul class="medium-columns"><li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/BFO_0000055' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000055'>BFO:0000055</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/BFO_0000054' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000054'>BFO:0000054</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/BFO_0000163' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000163'>BFO:0000163</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/MF#manifestationOf' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MF#manifestationOf'>OBO:MF#manifestationOf</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0010002' target='_blank' title='Go to Relation Ontology to get more informations about RO:0010002'>RO:0010002</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0010001' target='_blank' title='Go to Relation Ontology to get more informations about RO:0010001'>RO:0010001</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/BFO_0000117' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000117'>BFO:0000117</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/BFO_0000132' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000132'>BFO:0000132</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0000059' target='_blank' title='Go to Relation Ontology to get more informations about RO:0000059'>RO:0000059</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0000058' target='_blank' title='Go to Relation Ontology to get more informations about RO:0000058'>RO:0000058</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/OBI_0000417' target='_blank' title='Go to Ontology for Biomedical Investigations to get more informations about OBI:0000417'>OBI:0000417</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/OBI_0000833' target='_blank' title='Go to Ontology for Biomedical Investigations to get more informations about OBI:0000833'>OBI:0000833</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/BSPO_0000098' target='_blank' title='Go to Biological Spatial Ontology to get more informations about BSPO:0000098'>BSPO:0000098</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/BSPO_0000102' target='_blank' title='Go to Biological Spatial Ontology to get more informations about BSPO:0000102'>BSPO:0000102</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0002005' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002005'>RO:0002005</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0002134' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002134'>RO:0002134</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0001018' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001018'>RO:0001018</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0001019' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001019'>RO:0001019</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0001025' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001025'>RO:0001025</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0001015' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001015'>RO:0001015</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0003001' target='_blank' title='Go to Relation Ontology to get more informations about RO:0003001'>RO:0003001</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0003000' target='_blank' title='Go to Relation Ontology to get more informations about RO:0003000'>RO:0003000</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/BFO_0000066' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000066'>BFO:0000066</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/BFO_0000067' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000067'>BFO:0000067</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/chebi#is_conjugate_acid_of' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#is_conjugate_acid_of'>OBO:chebi#is_conjugate_acid_of</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/chebi#is_conjugate_base_of' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#is_conjugate_base_of'>OBO:chebi#is_conjugate_base_of</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.omim.org/entry/609062' target='_blank' title='Go to OMIN to get more informations about OMIM:609062'>OMIM:609062</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.omim.org/entry/601583' target='_blank' title='Go to OMIN to get more informations about OMIM:601583'>OMIM:601583</a> (node types <a href='https://biolink.github.io/biolink-model/docs/DiseaseOrPhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:DiseaseOrPhenotypicFeature'>biolink:DiseaseOrPhenotypicFeature</a>, <a href='https://biolink.github.io/biolink-model/docs/Disease.html' target='_blank' title='Go to BioLink to get more informations about biolink:Disease'>biolink:Disease</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://www.ncbi.nlm.nih.gov/gene/246319' target='_blank' title='Go to NCBI Gene to get more informations about NCBIGene:246319'>NCBIGene:246319</a> (node types <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>, <a href='https://biolink.github.io/biolink-model/docs/MolecularEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:MolecularEntity'>biolink:MolecularEntity</a>, <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a> and <a href='https://biolink.github.io/biolink-model/docs/NucleicAcidEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:NucleicAcidEntity'>biolink:NucleicAcidEntity</a>) and <a href='https://www.omim.org/entry/193200' target='_blank' title='Go to OMIN to get more informations about OMIM:193200'>OMIM:193200</a> (node types <a href='https://biolink.github.io/biolink-model/docs/DiseaseOrPhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:DiseaseOrPhenotypicFeature'>biolink:DiseaseOrPhenotypicFeature</a>, <a href='https://biolink.github.io/biolink-model/docs/Disease.html' target='_blank' title='Go to BioLink to get more informations about biolink:Disease'>biolink:Disease</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li></ul><p class="paragraph">And other 3.96K node tuples.</p><h4 style="margin: 1em 0 0 0;">Isomorphic node groups</h4><p class="paragraph">Isomorphic node groups are nodes with exactly the same neighbours, node types, edge types and weights (if present in the graph). Nodes in such groups are topologically indistinguishable, that is swapping their ID would not change the graph topology. We have detected 682 isomorphic node groups in the graph, involving a total of 3.44K nodes (0.62%) and 73.83K edges (1.30%), with the largest one involving 114 nodes and 2.78K edges. The detected isomorphic node groups, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Group with 5 nodes (degree 556 and node types <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>): <a href='https://www.ensembl.org/Gene/Summary?g=ENSP00000462355' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSP00000462355'>ENSEMBL:ENSP00000462355</a>, <a href='https://www.ensembl.org/Gene/Summary?g=ENSP00000479794' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSP00000479794'>ENSEMBL:ENSP00000479794</a>, <a href='https://www.ensembl.org/Gene/Summary?g=ENSP00000480960' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSP00000480960'>ENSEMBL:ENSP00000480960</a>, <a href='https://www.ensembl.org/Gene/Summary?g=ENSP00000479461' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSP00000479461'>ENSEMBL:ENSP00000479461</a> and <a href='https://www.ensembl.org/Gene/Summary?g=ENSP00000366956' target='_blank' title='Go to ENSEMBL to get more informations about ENSEMBL:ENSP00000366956'>ENSEMBL:ENSP00000366956</a>.</p></li>
# <li><p class="paragraph">Group with 114 nodes (degree 16 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/A0A0A6YVW3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A0A6YVW3'>UniProtKB:A0A0A6YVW3</a>, <a href='https://www.uniprot.org/uniprot/A0A0A6YW58' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A0A6YW58'>UniProtKB:A0A0A6YW58</a>, <a href='https://www.uniprot.org/uniprot/A0A0A6YWG4' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A0A6YWG4'>UniProtKB:A0A0A6YWG4</a>, <a href='https://www.uniprot.org/uniprot/A0A0A6YWI9' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A0A6YWI9'>UniProtKB:A0A0A6YWI9</a>, <a href='https://www.uniprot.org/uniprot/A0A0A6YXA5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A0A6YXA5'>UniProtKB:A0A0A6YXA5</a> and other 109.</p></li>
# <li><p class="paragraph">Group with 97 nodes (degree 16 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/F1PH61' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1PH61'>UniProtKB:F1PH61</a>, <a href='https://www.uniprot.org/uniprot/E2QXJ3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2QXJ3'>UniProtKB:E2QXJ3</a>, <a href='https://www.uniprot.org/uniprot/E2R7G9' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2R7G9'>UniProtKB:E2R7G9</a>, <a href='https://www.uniprot.org/uniprot/E2R8C5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2R8C5'>UniProtKB:E2R8C5</a>, <a href='https://www.uniprot.org/uniprot/A0A5F4DLE0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A5F4DLE0'>UniProtKB:A0A5F4DLE0</a> and other 92.</p></li>
# <li><p class="paragraph">Group with 81 nodes (degree 16 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/M0R8Q9' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:M0R8Q9'>UniProtKB:M0R8Q9</a>, <a href='https://www.uniprot.org/uniprot/P20767' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P20767'>UniProtKB:P20767</a>, <a href='https://www.uniprot.org/uniprot/P20766' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P20766'>UniProtKB:P20766</a>, <a href='https://www.uniprot.org/uniprot/A0A0G2JT95' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A0G2JT95'>UniProtKB:A0A0G2JT95</a>, <a href='https://www.uniprot.org/uniprot/A0A0G2JUY3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A0G2JUY3'>UniProtKB:A0A0G2JUY3</a> and other 76.</p></li>
# <li><p class="paragraph">Group with 26 nodes (degree 48 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q5W416' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q5W416'>UniProtKB:Q5W416</a>, <a href='https://www.uniprot.org/uniprot/F1PRW0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1PRW0'>UniProtKB:F1PRW0</a>, <a href='https://www.uniprot.org/uniprot/E2RA22' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2RA22'>UniProtKB:E2RA22</a>, <a href='https://www.uniprot.org/uniprot/F1PUB5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1PUB5'>UniProtKB:F1PUB5</a>, <a href='https://www.uniprot.org/uniprot/J9P849' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:J9P849'>UniProtKB:J9P849</a> and other 21.</p></li>
# <li><p class="paragraph">Group with 24 nodes (degree 48 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/O55234' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:O55234'>UniProtKB:O55234</a>, <a href='https://www.uniprot.org/uniprot/Q8BJY1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q8BJY1'>UniProtKB:Q8BJY1</a>, <a href='https://www.uniprot.org/uniprot/Q8BHL8' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q8BHL8'>UniProtKB:Q8BHL8</a>, <a href='https://www.uniprot.org/uniprot/Q9Z2X2' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9Z2X2'>UniProtKB:Q9Z2X2</a>, <a href='https://www.uniprot.org/uniprot/Q9CX56' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9CX56'>UniProtKB:Q9CX56</a> and other 19.</p></li>
# <li><p class="paragraph">Group with 26 nodes (degree 44 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q4KM35' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q4KM35'>UniProtKB:Q4KM35</a>, <a href='https://www.uniprot.org/uniprot/Q5FVM2' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q5FVM2'>UniProtKB:Q5FVM2</a>, <a href='https://www.uniprot.org/uniprot/P48004' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P48004'>UniProtKB:P48004</a>, <a href='https://www.uniprot.org/uniprot/A0A0G2JSL0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A0G2JSL0'>UniProtKB:A0A0G2JSL0</a>, <a href='https://www.uniprot.org/uniprot/P18422' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P18422'>UniProtKB:P18422</a> and other 21.</p></li>
# <li><p class="paragraph">Group with 24 nodes (degree 47 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q5E9K0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q5E9K0'>UniProtKB:Q5E9K0</a>, <a href='https://www.uniprot.org/uniprot/F1N6Z0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1N6Z0'>UniProtKB:F1N6Z0</a>, <a href='https://www.uniprot.org/uniprot/F1MLV1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1MLV1'>UniProtKB:F1MLV1</a>, <a href='https://www.uniprot.org/uniprot/Q3T030' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q3T030'>UniProtKB:Q3T030</a>, <a href='https://www.uniprot.org/uniprot/Q3T0X5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q3T0X5'>UniProtKB:Q3T0X5</a> and other 19.</p></li>
# <li><p class="paragraph">Group with 23 nodes (degree 48 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/A0A480QIP5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A480QIP5'>UniProtKB:A0A480QIP5</a>, <a href='https://www.uniprot.org/uniprot/Q2PYM7' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q2PYM7'>UniProtKB:Q2PYM7</a>, <a href='https://www.uniprot.org/uniprot/Q64L94' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q64L94'>UniProtKB:Q64L94</a>, <a href='https://www.uniprot.org/uniprot/A0A288CG47' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A288CG47'>UniProtKB:A0A288CG47</a>, <a href='https://www.uniprot.org/uniprot/A0A287BTN9' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A287BTN9'>UniProtKB:A0A287BTN9</a> and other 18.</p></li>
# <li><p class="paragraph">Group with 57 nodes (degree 19 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/A2NJV5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A2NJV5'>UniProtKB:A2NJV5</a>, <a href='https://www.uniprot.org/uniprot/P01709' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P01709'>UniProtKB:P01709</a>, <a href='https://www.uniprot.org/uniprot/P01611' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P01611'>UniProtKB:P01611</a>, <a href='https://www.uniprot.org/uniprot/P01814' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P01814'>UniProtKB:P01814</a>, <a href='https://www.uniprot.org/uniprot/P04432' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P04432'>UniProtKB:P04432</a> and other 52.</p></li>
# <li><p class="paragraph">Group with 24 nodes (degree 44 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q7ZUJ8' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q7ZUJ8'>UniProtKB:Q7ZUJ8</a>, <a href='https://www.uniprot.org/uniprot/Q7ZV77' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q7ZV77'>UniProtKB:Q7ZV77</a>, <a href='https://www.uniprot.org/uniprot/A0A0R4II16' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A0R4II16'>UniProtKB:A0A0R4II16</a>, <a href='https://www.uniprot.org/uniprot/Q9PUS3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9PUS3'>UniProtKB:Q9PUS3</a>, <a href='https://www.uniprot.org/uniprot/Q9PUC4' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9PUC4'>UniProtKB:Q9PUC4</a> and other 19.</p></li>
# ...
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='https://reactome.org/content/detail/R-HSA-1606584' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1606584'>REACT:R-HSA-1606584</a> (degree 3), and containing 5 nodes, with a maximal depth of 2, which are <a href='https://reactome.org/content/detail/R-HSA-1606575' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1606575'>REACT:R-HSA-1606575</a>, <a href='https://reactome.org/content/detail/R-HSA-1605675' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1605675'>REACT:R-HSA-1605675</a>, <a href='https://reactome.org/content/detail/R-HSA-1605710' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1605710'>REACT:R-HSA-1605710</a> and <a href='https://reactome.org/content/detail/R-HSA-1606814' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1606814'>REACT:R-HSA-1606814</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/Pathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:Pathway'>biolink:Pathway</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/related_to.html' target='_blank' title='Go to BioLink to get more informations about biolink:related_to'>biolink:related_to</a>.</p></li>
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='https://reactome.org/content/detail/R-HSA-1252240' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1252240'>REACT:R-HSA-1252240</a> (degree 3), and containing 5 nodes, with a maximal depth of 2, which are <a href='https://reactome.org/content/detail/R-HSA-1252098' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1252098'>REACT:R-HSA-1252098</a>, <a href='https://reactome.org/content/detail/R-HSA-1252247' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1252247'>REACT:R-HSA-1252247</a>, <a href='https://reactome.org/content/detail/R-HSA-1252140' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1252140'>REACT:R-HSA-1252140</a> and <a href='https://reactome.org/content/detail/R-HSA-1955377' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1955377'>REACT:R-HSA-1955377</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/Pathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:Pathway'>biolink:Pathway</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/precedes.html' target='_blank' title='Go to BioLink to get more informations about biolink:precedes'>biolink:precedes</a>.</p></li>
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='https://www.omim.org/entry/155555' target='_blank' title='Go to OMIN to get more informations about OMIM:155555'>OMIM:155555</a> (degree 3 and node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), and containing 5 nodes, with a maximal depth of 2, which are <a href='https://www.omim.org/entry/203200' target='_blank' title='Go to OMIN to get more informations about OMIM:203200'>OMIM:203200</a> (node types <a href='https://biolink.github.io/biolink-model/docs/DiseaseOrPhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:DiseaseOrPhenotypicFeature'>biolink:DiseaseOrPhenotypicFeature</a>, <a href='https://biolink.github.io/biolink-model/docs/Disease.html' target='_blank' title='Go to BioLink to get more informations about biolink:Disease'>biolink:Disease</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.omim.org/entry/613099' target='_blank' title='Go to OMIN to get more informations about OMIM:613099'>OMIM:613099</a> (node types <a href='https://biolink.github.io/biolink-model/docs/DiseaseOrPhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:DiseaseOrPhenotypicFeature'>biolink:DiseaseOrPhenotypicFeature</a>, <a href='https://biolink.github.io/biolink-model/docs/Disease.html' target='_blank' title='Go to BioLink to get more informations about biolink:Disease'>biolink:Disease</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.omim.org/entry/266300' target='_blank' title='Go to OMIN to get more informations about OMIM:266300'>OMIM:266300</a> (node types <a href='https://biolink.github.io/biolink-model/docs/DiseaseOrPhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:DiseaseOrPhenotypicFeature'>biolink:DiseaseOrPhenotypicFeature</a>, <a href='https://biolink.github.io/biolink-model/docs/Disease.html' target='_blank' title='Go to BioLink to get more informations about biolink:Disease'>biolink:Disease</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='https://www.omim.org/entry/611409' target='_blank' title='Go to OMIN to get more informations about OMIM:611409'>OMIM:611409</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Gene.html' target='_blank' title='Go to BioLink to get more informations about biolink:Gene'>biolink:Gene</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>). Its nodes have 4 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (4 nodes), <a href='https://biolink.github.io/biolink-model/docs/DiseaseOrPhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:DiseaseOrPhenotypicFeature'>biolink:DiseaseOrPhenotypicFeature</a> (3 nodes), <a href='https://biolink.github.io/biolink-model/docs/Disease.html' target='_blank' title='Go to BioLink to get more informations about biolink:Dis ...
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=43741' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:43741'>NCBITaxon:43741</a> (degree 3), and containing 9 nodes, with a maximal depth of 9, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=43746' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:43746'>NCBITaxon:43746</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7214' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7214'>NCBITaxon:7214</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=43845' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:43845'>NCBITaxon:43845</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=46877' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:46877'>NCBITaxon:46877</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7215' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7215'>NCBITaxon:7215</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2698737' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2698737'>NCBITaxon:2698737</a> (degree 4), and containing 7 nodes, with a maximal depth of 7, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=543769' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:543769'>NCBITaxon:543769</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2662056' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2662056'>NCBITaxon:2662056</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=29178' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:29178'>NCBITaxon:29178</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=29185' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:29185'>NCBITaxon:29185</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=203397' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:203397'>NCBITaxon:203397</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://reactome.org/content/detail/R-HSA-5694523' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-5694523'>REACT:R-HSA-5694523</a> (degree 4), and containing 7 nodes, with a maximal depth of 7, which are <a href='https://reactome.org/content/detail/R-HSA-5694339' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-5694339'>REACT:R-HSA-5694339</a> (degree 3), <a href='https://reactome.org/content/detail/R-HSA-5694337' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-5694337'>REACT:R-HSA-5694337</a> (degree 3), <a href='https://reactome.org/content/detail/R-HSA-5694329' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-5694329'>REACT:R-HSA-5694329</a> (degree 3), <a href='https://reactome.org/content/detail/R-HSA-5694315' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-5694315'>REACT:R-HSA-5694315</a> (degree 3) and <a href='https://reactome.org/content/detail/R-HSA-5694330' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-5694330'>REACT:R-HSA-5694330</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/Pathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:Pathway'>biolink:Pathway</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/positively_regulates.html' target='_blank' title='Go to BioLink to get more informations about biolink:positively_regulates'>biolink:positively_regulates</a> (9 edges, 52.94%) and <a href='https://biolink.github.io/biolink-model/docs/related_to.html' target='_blank' title='Go to BioLink to get more informations about biolink:related_to'>biolink:related_to</a> (8 edges, 47.06%).</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=6236' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:6236'>NCBITaxon:6236</a> (degree 5), and containing 6 nodes, with a maximal depth of 6, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2301116' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2301116'>NCBITaxon:2301116</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2301119' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2301119'>NCBITaxon:2301119</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=55879' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:55879'>NCBITaxon:55879</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=6243' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:6243'>NCBITaxon:6243</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=55885' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:55885'>NCBITaxon:55885</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://reactome.org/content/detail/R-HSA-70495' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-70495'>REACT:R-HSA-70495</a> (degree 4), and containing 6 nodes, with a maximal depth of 6, which are <a href='https://reactome.org/content/detail/R-HSA-70579' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-70579'>REACT:R-HSA-70579</a>, <a href='https://reactome.org/content/detail/R-HSA-1237173' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1237173'>REACT:R-HSA-1237173</a>, <a href='https://reactome.org/content/detail/R-HSA-1237166' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1237166'>REACT:R-HSA-1237166</a>, <a href='https://reactome.org/content/detail/R-HSA-1237083' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1237083'>REACT:R-HSA-1237083</a> and <a href='https://reactome.org/content/detail/R-HSA-1237095' target='_blank' title='Go to Reactome to get more informations about REACT:R-HSA-1237095'>REACT:R-HSA-1237095</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/Pathway.html' target='_blank' title='Go to BioLink to get more informations about biolink:Pathway'>biolink:Pathway</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/precedes.html' target='_blank' title='Go to BioLink to get more informations about biolink:precedes'>biolink:precedes</a> (6 edges, 54.55%) and <a href='https://biolink.github.io/biolink-model/docs/related_to.html' target='_blank' title='Go to BioLink to get more informations about biolink:related_to'>biolink:related_to</a> (5 edges, 45.45%).</p></li></ol><p class="paragraph">And other 8.35K tendrils.</p></div>

# %%
main_component = g.remove_components(top_k_components=1)
dense_main_component = main_component.remove_dendritic_trees()
dense_main_component
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>KGIDG</h2><p class="paragraph">The undirected multigraph KGIDG has 239.59K heterogeneous nodes and 1.01M heterogeneous edges. The graph is connected, that is, it is composed of a single connected component that includes all nodes and edges. The RAM requirements for the nodes and edges data structures are 28.58MB and 9.97MB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 2, the maximum node degree is 9.36K, the mode degree is 2, the mean degree is 8.41 and the node degree median is 4.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='http://amigo.geneontology.org/amigo/term/GO:0065007' target='_blank' title='Go to Gene Ontology to get more informations about GO:0065007'>GO:0065007</a> (degree 9.36K and node types <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcess.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcess'>biolink:BiologicalProcess</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:24995' target='_blank' title='Go to CHEBI to get more informations about CHEBI:24995'>CHEBI:24995</a> (degree 7.34K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:52898' target='_blank' title='Go to CHEBI to get more informations about CHEBI:52898'>CHEBI:52898</a> (degree 7.26K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:30616' target='_blank' title='Go to CHEBI to get more informations about CHEBI:30616'>CHEBI:30616</a> (degree 6.01K and node types <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a> and <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:456216' target='_blank' title='Go to CHEBI to get more informations about CHEBI:456216'>CHEBI:456216</a> (degree 5.44K and node types <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a> and <a ...
# <li><p class="paragraph">Chain containing 10 nodes and starts from the node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=70999' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:70999'>NCBITaxon:70999</a>. Specifically, the nodes involved in the chain are: <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=27479' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:27479'>NCBITaxon:27479</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33356' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33356'>NCBITaxon:33356</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33354' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33354'>NCBITaxon:33354</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33351' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33351'>NCBITaxon:33351</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33349' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33349'>NCBITaxon:33349</a> and other 4. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (19 edges, 95.00%) and <a href='https://biolink.github.io/biolink-model/docs/related_to.html' target='_blank' title='Go to BioLink to get more informations about biolink:related_to'>biolink:related_to</a>.</p></li></ol><h4 style="margin: 1em 0 0 0;">Isomorphic node groups</h4><p class="paragraph">Isomorphic node groups are nodes with exactly the same neighbours, node types, edge types and weights (if present in the graph). Nodes in such groups are topologically indistinguishable, that is swapping their ID would not change the graph topology. We have detected 671 isomorphic node groups in the graph, involving a total of 3.40K nodes (1.42%) and 68.88K edges (3.42%), with the largest one involving 114 nodes and 1.82K edges. The detected isomorphic node groups, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Group with 114 nodes (degree 16 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/P18531' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P18531'>UniProtKB:P18531</a>, <a href='https://www.uniprot.org/uniprot/A0A075B5J7' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A075B5J7'>UniProtKB:A0A075B5J7</a>, <a href='https://www.uniprot.org/uniprot/A0A075B5J9' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A075B5J9'>UniProtKB:A0A075B5J9</a>, <a href='https://www.uniprot.org/uniprot/A0A075B5K0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A075B5K0'>UniProtKB:A0A075B5K0</a>, <a href='https://www.uniprot.org/uniprot/A0A075B5K3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A075B5K3'>UniProtKB:A0A075B5K3</a> and other 109.</p></li>
# <li><p class="paragraph">Group with 97 nodes (degree 16 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/F1PH61' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1PH61'>UniProtKB:F1PH61</a>, <a href='https://www.uniprot.org/uniprot/H9GWR0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:H9GWR0'>UniProtKB:H9GWR0</a>, <a href='https://www.uniprot.org/uniprot/E2QXJ3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2QXJ3'>UniProtKB:E2QXJ3</a>, <a href='https://www.uniprot.org/uniprot/F1PQU0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1PQU0'>UniProtKB:F1PQU0</a>, <a href='https://www.uniprot.org/uniprot/E2R7G9' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2R7G9'>UniProtKB:E2R7G9</a> and other 92.</p></li>
# <li><p class="paragraph">Group with 81 nodes (degree 16 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/D4ADL1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:D4ADL1'>UniProtKB:D4ADL1</a>, <a href='https://www.uniprot.org/uniprot/D4ADK9' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:D4ADK9'>UniProtKB:D4ADK9</a>, <a href='https://www.uniprot.org/uniprot/D4A5Y5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:D4A5Y5'>UniProtKB:D4A5Y5</a>, <a href='https://www.uniprot.org/uniprot/D4A4L6' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:D4A4L6'>UniProtKB:D4A4L6</a>, <a href='https://www.uniprot.org/uniprot/D4A3L8' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:D4A3L8'>UniProtKB:D4A3L8</a> and other 76.</p></li>
# <li><p class="paragraph">Group with 26 nodes (degree 48 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/E2R3R2' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2R3R2'>UniProtKB:E2R3R2</a>, <a href='https://www.uniprot.org/uniprot/J9P849' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:J9P849'>UniProtKB:J9P849</a>, <a href='https://www.uniprot.org/uniprot/Q5W416' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q5W416'>UniProtKB:Q5W416</a>, <a href='https://www.uniprot.org/uniprot/E2RMN2' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2RMN2'>UniProtKB:E2RMN2</a>, <a href='https://www.uniprot.org/uniprot/E2RM61' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2RM61'>UniProtKB:E2RM61</a> and other 21.</p></li>
# <li><p class="paragraph">Group with 24 nodes (degree 48 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q9Z2U0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9Z2U0'>UniProtKB:Q9Z2U0</a>, <a href='https://www.uniprot.org/uniprot/Q9R1P1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9R1P1'>UniProtKB:Q9R1P1</a>, <a href='https://www.uniprot.org/uniprot/Q8BHL8' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q8BHL8'>UniProtKB:Q8BHL8</a>, <a href='https://www.uniprot.org/uniprot/Q9Z2X2' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9Z2X2'>UniProtKB:Q9Z2X2</a>, <a href='https://www.uniprot.org/uniprot/Q9R1P3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9R1P3'>UniProtKB:Q9R1P3</a> and other 19.</p></li>
# <li><p class="paragraph">Group with 26 nodes (degree 44 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/P28075' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P28075'>UniProtKB:P28075</a>, <a href='https://www.uniprot.org/uniprot/Q4KM35' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q4KM35'>UniProtKB:Q4KM35</a>, <a href='https://www.uniprot.org/uniprot/P48004' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P48004'>UniProtKB:P48004</a>, <a href='https://www.uniprot.org/uniprot/P40307' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P40307'>UniProtKB:P40307</a>, <a href='https://www.uniprot.org/uniprot/P34067' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P34067'>UniProtKB:P34067</a> and other 21.</p></li>
# <li><p class="paragraph">Group with 24 nodes (degree 47 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q3T0X5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q3T0X5'>UniProtKB:Q3T0X5</a>, <a href='https://www.uniprot.org/uniprot/Q58DU5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q58DU5'>UniProtKB:Q58DU5</a>, <a href='https://www.uniprot.org/uniprot/F1MLV1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1MLV1'>UniProtKB:F1MLV1</a>, <a href='https://www.uniprot.org/uniprot/Q3T030' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q3T030'>UniProtKB:Q3T030</a>, <a href='https://www.uniprot.org/uniprot/P62194' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P62194'>UniProtKB:P62194</a> and other 19.</p></li>
# <li><p class="paragraph">Group with 23 nodes (degree 48 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/A0A287B4P8' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A287B4P8'>UniProtKB:A0A287B4P8</a>, <a href='https://www.uniprot.org/uniprot/F1SGM3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1SGM3'>UniProtKB:F1SGM3</a>, <a href='https://www.uniprot.org/uniprot/Q64L94' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q64L94'>UniProtKB:Q64L94</a>, <a href='https://www.uniprot.org/uniprot/P62197' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P62197'>UniProtKB:P62197</a>, <a href='https://www.uniprot.org/uniprot/A0A287B5Q7' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A287B5Q7'>UniProtKB:A0A287B5Q7</a> and other 18.</p></li>
# <li><p class="paragraph">Group with 58 nodes (degree 19 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q6PIL0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q6PIL0'>UniProtKB:Q6PIL0</a>, <a href='https://www.uniprot.org/uniprot/P01611' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P01611'>UniProtKB:P01611</a>, <a href='https://www.uniprot.org/uniprot/P01709' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P01709'>UniProtKB:P01709</a>, <a href='https://www.uniprot.org/uniprot/P01814' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P01814'>UniProtKB:P01814</a>, <a href='https://www.uniprot.org/uniprot/P04432' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P04432'>UniProtKB:P04432</a> and other 53.</p></li>
# <li><p class="paragraph">Group with 24 nodes (degree 44 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/O57330' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:O57330'>UniProtKB:O57330</a>, <a href='https://www.uniprot.org/uniprot/Q9PTH5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9PTH5'>UniProtKB:Q9PTH5</a>, <a href='https://www.uniprot.org/uniprot/Q6DGX8' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q6DGX8'>UniProtKB:Q6DGX8</a>, <a href='https://www.uniprot.org/uniprot/Q6AZC1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q6AZC1'>UniProtKB:Q6AZC1</a>, <a href='https://www.uniprot.org/uniprot/Q7ZV77' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q7ZV77'>UniProtKB:Q7ZV77</a> and other 19.</p></li>
# <li><p class="paragraph">Group with 33 nodes (degree 29 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/G3N011' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:G3N011'>UniProtKB:G3N011</a>, <a href='https://www.uniprot.org/uniprot/E1BAA6' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E1BAA6'>UniProtKB:E1BAA6</a>, <a href='https://www.uniprot.org/uniprot/A0A3Q1MEU7' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A3Q1MEU7'>UniProtKB:A0A3Q1MEU7</a>, <a href='https://www.uniprot.org/uniprot/E1B975' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E1B975'>UniProtKB:E1B975</a>, <a href='https://www.uniprot.org/uniprot/G3MXG1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:G3MXG1'>UniProtKB:G3MXG1</a> and other 28.</p></li>
# <li><p class="paragraph">Group with 84 nodes (degree 11 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/A0A3Q2TT43' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A3Q2TT43'>UniProtKB:A0A3Q2TT43</a>, <a href='https://www.uniprot.org/uniprot/R9PXM5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:R9PXM5'>UniProtKB:R9PXM5</a>, <a href='https://www.uniprot.org/uniprot/A0A3Q3AZS4' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A3Q3AZS4'>UniProtKB:A0A3Q3AZS4</a>, <a href='https://www.uniprot.org/uniprot/A0A3Q3AV59' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A3Q3AV59'>UniProtKB:A0A3Q3AV59</a>, <a href='https://www.uniprot.org/uniprot/A0A3Q3ARD4' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A3Q3ARD4'>UniProtKB:A0A3Q3ARD4</a> and other 79.</p></li>
# <li><p class="paragraph">Group with 14 nodes (degree 49 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q9WVJ2' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9WVJ2'>UniProtKB:Q9WVJ2</a>, <a href='https://www.uniprot.org/uniprot/P46471' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P46471'>UniProtKB:P46471</a>, <a href='https://www.uniprot.org/uniprot/Q3TXS7' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q3TXS7'>UniProtKB:Q3TXS7</a>, <a href='https://www.uniprot.org/uniprot/Q9Z2U1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9Z2U1'>UniProtKB:Q9Z2U1</a>, <a href='https://www.uniprot.org/uniprot/Q9D8W5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9D8W5'>UniProtKB:Q9D8W5</a> and other 9.</p></li>
# <li><p class="paragraph">Group with 13 nodes (degree 52 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q9V3V6' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9V3V6'>UniProtKB:Q9V3V6</a>, <a href='https://www.uniprot.org/uniprot/Q9VW54' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9VW54'>UniProtKB:Q9VW54</a>, <a href='https://www.uniprot.org/uniprot/Q9VUJ1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9VUJ1'>UniProtKB:Q9VUJ1</a>, <a href='https://www.uniprot.org/uniprot/Q9V3P6' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9V3P6'>UniProtKB:Q9V3P6</a>, <a href='https://www.uniprot.org/uniprot/Q95083' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q95083'>UniProtKB:Q95083</a> and other 8.</p></li>
# <li><p class="paragraph">Group with 14 nodes (degree 48 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/F1MXE4' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1MXE4'>UniProtKB:F1MXE4</a>, <a href='https://www.uniprot.org/uniprot/Q5E964' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q5E964'>UniProtKB:Q5E964</a>, <a href='https://www.uniprot.org/uniprot/Q5E987' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q5E987'>UniProtKB:Q5E987</a>, <a href='https://www.uniprot.org/uniprot/A7MBA2' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A7MBA2'>UniProtKB:A7MBA2</a>, <a href='https://www.uniprot.org/uniprot/F1MBI1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1MBI1'>UniProtKB:F1MBI1</a> and other 9.</p></li></ol><p class="paragraph">And other 656 isomorphic node groups.</p></div>

# %%
drug_types = ["biolink:ChemicalSubstance", "biolink:ChemicalEntity", "biolink:Drug"]
# edge_of_interest = ["biolink:interacts_with", "biolink:molecularly_interacts_with", "biolink:physically_interacts_with"]
protein_types = ["biolink:Protein"]
minority_edge_type = 'minority_edge'

dense_main_component.replace_edge_type_name_from_edge_node_type_names_inplace(
    edge_type_name=minority_edge_type,
    source_node_type_names=drug_types,
    destination_node_type_names=protein_types
)
dense_main_component
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>KGIDG</h2><p class="paragraph">The undirected multigraph KGIDG has 239.59K heterogeneous nodes and 1.01M heterogeneous edges. The graph is connected, that is, it is composed of a single connected component that includes all nodes and edges. The RAM requirements for the nodes and edges data structures are 28.58MB and 9.97MB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 2, the maximum node degree is 9.36K, the mode degree is 2, the mean degree is 8.41 and the node degree median is 4.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='http://amigo.geneontology.org/amigo/term/GO:0065007' target='_blank' title='Go to Gene Ontology to get more informations about GO:0065007'>GO:0065007</a> (degree 9.36K and node types <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcess.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcess'>biolink:BiologicalProcess</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:24995' target='_blank' title='Go to CHEBI to get more informations about CHEBI:24995'>CHEBI:24995</a> (degree 7.34K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:52898' target='_blank' title='Go to CHEBI to get more informations about CHEBI:52898'>CHEBI:52898</a> (degree 7.26K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a>), <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:30616' target='_blank' title='Go to CHEBI to get more informations about CHEBI:30616'>CHEBI:30616</a> (degree 6.01K and node types <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a> and <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>) and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:456216' target='_blank' title='Go to CHEBI to get more informations about CHEBI:456216'>CHEBI:456216</a> (degree 5.44K and node types <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a> and <a ...
# <li><p class="paragraph">Chain containing 10 nodes and starts from the node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=70999' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:70999'>NCBITaxon:70999</a>. Specifically, the nodes involved in the chain are: <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=27479' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:27479'>NCBITaxon:27479</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33356' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33356'>NCBITaxon:33356</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33354' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33354'>NCBITaxon:33354</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33351' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33351'>NCBITaxon:33351</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33349' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33349'>NCBITaxon:33349</a> and other 4. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (19 edges, 95.00%) and <a href='https://biolink.github.io/biolink-model/docs/related_to.html' target='_blank' title='Go to BioLink to get more informations about biolink:related_to'>biolink:related_to</a>.</p></li></ol><h4 style="margin: 1em 0 0 0;">Isomorphic node groups</h4><p class="paragraph">Isomorphic node groups are nodes with exactly the same neighbours, node types, edge types and weights (if present in the graph). Nodes in such groups are topologically indistinguishable, that is swapping their ID would not change the graph topology. We have detected 671 isomorphic node groups in the graph, involving a total of 3.40K nodes (1.42%) and 68.88K edges (3.42%), with the largest one involving 114 nodes and 1.82K edges. The detected isomorphic node groups, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Group with 114 nodes (degree 16 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/P18531' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P18531'>UniProtKB:P18531</a>, <a href='https://www.uniprot.org/uniprot/A0A075B5J7' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A075B5J7'>UniProtKB:A0A075B5J7</a>, <a href='https://www.uniprot.org/uniprot/A0A075B5J9' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A075B5J9'>UniProtKB:A0A075B5J9</a>, <a href='https://www.uniprot.org/uniprot/A0A075B5K0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A075B5K0'>UniProtKB:A0A075B5K0</a>, <a href='https://www.uniprot.org/uniprot/A0A075B5K3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A075B5K3'>UniProtKB:A0A075B5K3</a> and other 109.</p></li>
# <li><p class="paragraph">Group with 97 nodes (degree 16 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/F1PH61' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1PH61'>UniProtKB:F1PH61</a>, <a href='https://www.uniprot.org/uniprot/H9GWR0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:H9GWR0'>UniProtKB:H9GWR0</a>, <a href='https://www.uniprot.org/uniprot/E2QXJ3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2QXJ3'>UniProtKB:E2QXJ3</a>, <a href='https://www.uniprot.org/uniprot/F1PQU0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1PQU0'>UniProtKB:F1PQU0</a>, <a href='https://www.uniprot.org/uniprot/E2R7G9' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2R7G9'>UniProtKB:E2R7G9</a> and other 92.</p></li>
# <li><p class="paragraph">Group with 81 nodes (degree 16 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/D4ADL1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:D4ADL1'>UniProtKB:D4ADL1</a>, <a href='https://www.uniprot.org/uniprot/D4ADK9' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:D4ADK9'>UniProtKB:D4ADK9</a>, <a href='https://www.uniprot.org/uniprot/D4A5Y5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:D4A5Y5'>UniProtKB:D4A5Y5</a>, <a href='https://www.uniprot.org/uniprot/D4A4L6' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:D4A4L6'>UniProtKB:D4A4L6</a>, <a href='https://www.uniprot.org/uniprot/D4A3L8' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:D4A3L8'>UniProtKB:D4A3L8</a> and other 76.</p></li>
# <li><p class="paragraph">Group with 26 nodes (degree 48 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/E2R3R2' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2R3R2'>UniProtKB:E2R3R2</a>, <a href='https://www.uniprot.org/uniprot/J9P849' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:J9P849'>UniProtKB:J9P849</a>, <a href='https://www.uniprot.org/uniprot/Q5W416' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q5W416'>UniProtKB:Q5W416</a>, <a href='https://www.uniprot.org/uniprot/E2RMN2' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2RMN2'>UniProtKB:E2RMN2</a>, <a href='https://www.uniprot.org/uniprot/E2RM61' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E2RM61'>UniProtKB:E2RM61</a> and other 21.</p></li>
# <li><p class="paragraph">Group with 24 nodes (degree 48 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q9Z2U0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9Z2U0'>UniProtKB:Q9Z2U0</a>, <a href='https://www.uniprot.org/uniprot/Q9R1P1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9R1P1'>UniProtKB:Q9R1P1</a>, <a href='https://www.uniprot.org/uniprot/Q8BHL8' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q8BHL8'>UniProtKB:Q8BHL8</a>, <a href='https://www.uniprot.org/uniprot/Q9Z2X2' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9Z2X2'>UniProtKB:Q9Z2X2</a>, <a href='https://www.uniprot.org/uniprot/Q9R1P3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9R1P3'>UniProtKB:Q9R1P3</a> and other 19.</p></li>
# <li><p class="paragraph">Group with 26 nodes (degree 44 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/P28075' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P28075'>UniProtKB:P28075</a>, <a href='https://www.uniprot.org/uniprot/Q4KM35' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q4KM35'>UniProtKB:Q4KM35</a>, <a href='https://www.uniprot.org/uniprot/P48004' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P48004'>UniProtKB:P48004</a>, <a href='https://www.uniprot.org/uniprot/P40307' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P40307'>UniProtKB:P40307</a>, <a href='https://www.uniprot.org/uniprot/P34067' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P34067'>UniProtKB:P34067</a> and other 21.</p></li>
# <li><p class="paragraph">Group with 24 nodes (degree 47 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q3T0X5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q3T0X5'>UniProtKB:Q3T0X5</a>, <a href='https://www.uniprot.org/uniprot/Q58DU5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q58DU5'>UniProtKB:Q58DU5</a>, <a href='https://www.uniprot.org/uniprot/F1MLV1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1MLV1'>UniProtKB:F1MLV1</a>, <a href='https://www.uniprot.org/uniprot/Q3T030' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q3T030'>UniProtKB:Q3T030</a>, <a href='https://www.uniprot.org/uniprot/P62194' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P62194'>UniProtKB:P62194</a> and other 19.</p></li>
# <li><p class="paragraph">Group with 23 nodes (degree 48 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/A0A287B4P8' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A287B4P8'>UniProtKB:A0A287B4P8</a>, <a href='https://www.uniprot.org/uniprot/F1SGM3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1SGM3'>UniProtKB:F1SGM3</a>, <a href='https://www.uniprot.org/uniprot/Q64L94' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q64L94'>UniProtKB:Q64L94</a>, <a href='https://www.uniprot.org/uniprot/P62197' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P62197'>UniProtKB:P62197</a>, <a href='https://www.uniprot.org/uniprot/A0A287B5Q7' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A287B5Q7'>UniProtKB:A0A287B5Q7</a> and other 18.</p></li>
# <li><p class="paragraph">Group with 58 nodes (degree 19 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q6PIL0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q6PIL0'>UniProtKB:Q6PIL0</a>, <a href='https://www.uniprot.org/uniprot/P01611' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P01611'>UniProtKB:P01611</a>, <a href='https://www.uniprot.org/uniprot/P01709' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P01709'>UniProtKB:P01709</a>, <a href='https://www.uniprot.org/uniprot/P01814' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P01814'>UniProtKB:P01814</a>, <a href='https://www.uniprot.org/uniprot/P04432' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P04432'>UniProtKB:P04432</a> and other 53.</p></li>
# <li><p class="paragraph">Group with 24 nodes (degree 44 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/O57330' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:O57330'>UniProtKB:O57330</a>, <a href='https://www.uniprot.org/uniprot/Q9PTH5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9PTH5'>UniProtKB:Q9PTH5</a>, <a href='https://www.uniprot.org/uniprot/Q6DGX8' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q6DGX8'>UniProtKB:Q6DGX8</a>, <a href='https://www.uniprot.org/uniprot/Q6AZC1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q6AZC1'>UniProtKB:Q6AZC1</a>, <a href='https://www.uniprot.org/uniprot/Q7ZV77' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q7ZV77'>UniProtKB:Q7ZV77</a> and other 19.</p></li>
# <li><p class="paragraph">Group with 33 nodes (degree 29 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/G3N011' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:G3N011'>UniProtKB:G3N011</a>, <a href='https://www.uniprot.org/uniprot/E1BAA6' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E1BAA6'>UniProtKB:E1BAA6</a>, <a href='https://www.uniprot.org/uniprot/A0A3Q1MEU7' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A3Q1MEU7'>UniProtKB:A0A3Q1MEU7</a>, <a href='https://www.uniprot.org/uniprot/E1B975' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:E1B975'>UniProtKB:E1B975</a>, <a href='https://www.uniprot.org/uniprot/G3MXG1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:G3MXG1'>UniProtKB:G3MXG1</a> and other 28.</p></li>
# <li><p class="paragraph">Group with 84 nodes (degree 11 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/A0A3Q2TT43' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A3Q2TT43'>UniProtKB:A0A3Q2TT43</a>, <a href='https://www.uniprot.org/uniprot/R9PXM5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:R9PXM5'>UniProtKB:R9PXM5</a>, <a href='https://www.uniprot.org/uniprot/A0A3Q3AZS4' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A3Q3AZS4'>UniProtKB:A0A3Q3AZS4</a>, <a href='https://www.uniprot.org/uniprot/A0A3Q3AV59' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A3Q3AV59'>UniProtKB:A0A3Q3AV59</a>, <a href='https://www.uniprot.org/uniprot/A0A3Q3ARD4' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A3Q3ARD4'>UniProtKB:A0A3Q3ARD4</a> and other 79.</p></li>
# <li><p class="paragraph">Group with 14 nodes (degree 49 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q9WVJ2' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9WVJ2'>UniProtKB:Q9WVJ2</a>, <a href='https://www.uniprot.org/uniprot/P46471' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P46471'>UniProtKB:P46471</a>, <a href='https://www.uniprot.org/uniprot/Q3TXS7' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q3TXS7'>UniProtKB:Q3TXS7</a>, <a href='https://www.uniprot.org/uniprot/Q9Z2U1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9Z2U1'>UniProtKB:Q9Z2U1</a>, <a href='https://www.uniprot.org/uniprot/Q9D8W5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9D8W5'>UniProtKB:Q9D8W5</a> and other 9.</p></li>
# <li><p class="paragraph">Group with 13 nodes (degree 52 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/Q9V3V6' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9V3V6'>UniProtKB:Q9V3V6</a>, <a href='https://www.uniprot.org/uniprot/Q9VW54' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9VW54'>UniProtKB:Q9VW54</a>, <a href='https://www.uniprot.org/uniprot/Q9VUJ1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9VUJ1'>UniProtKB:Q9VUJ1</a>, <a href='https://www.uniprot.org/uniprot/Q9V3P6' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q9V3P6'>UniProtKB:Q9V3P6</a>, <a href='https://www.uniprot.org/uniprot/Q95083' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q95083'>UniProtKB:Q95083</a> and other 8.</p></li>
# <li><p class="paragraph">Group with 14 nodes (degree 48 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/F1MXE4' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1MXE4'>UniProtKB:F1MXE4</a>, <a href='https://www.uniprot.org/uniprot/Q5E964' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q5E964'>UniProtKB:Q5E964</a>, <a href='https://www.uniprot.org/uniprot/Q5E987' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:Q5E987'>UniProtKB:Q5E987</a>, <a href='https://www.uniprot.org/uniprot/A7MBA2' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A7MBA2'>UniProtKB:A7MBA2</a>, <a href='https://www.uniprot.org/uniprot/F1MBI1' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:F1MBI1'>UniProtKB:F1MBI1</a> and other 9.</p></li></ol><p class="paragraph">And other 656 isomorphic node groups.</p></div>

# %% [markdown]
# # Classification
# The following code snippet shows the code used to test UND and DANS. Note that here, we set SmokeTest to True (which tests the pipeline without actually running the ML code). For the actual analysis, a comparable script was run with SmokeTest set to False.

# %%
from tqdm import tqdm
import pandas as pd
from grape.edge_prediction import edge_prediction_evaluation
from grape.edge_prediction import PerceptronEdgePrediction
# Set smoke test to True for testing:
SMOKE_TEST = True
NUMBER_OF_HOLDOUTS = 10
VALIDATION_UNBALANCE_RATES = (1.0, )
TRAIN_SIZES = (0.75,)

subgraph = dense_main_component.filter_from_names(
    edge_type_names_to_keep=["minority_edge"]
)

results = []

fresults = []
train_size = 0.75
for validation_use_scale_free in tqdm(
    (True, False),
    desc="Validation use scale free",
    leave=False
    ):
    results.append(edge_prediction_evaluation(
        smoke_test=SMOKE_TEST,
        holdouts_kwargs=dict(
            train_size=train_size,
            edge_types=["minority_edge"],
        ),
        evaluation_schema="Connected Monte Carlo",
        graphs=dense_main_component,
        models=[
            PerceptronEdgePrediction(
               edge_features=edge_feature,
                number_of_epochs=1000,
                number_of_edges_per_mini_batch=16,
                learning_rate=0.001,
                use_scale_free_distribution=False
            ) for edge_feature in("Degree","AdamicAdar","JaccardCoefficient","ResourceAllocationIndex","PreferentialAttachment")
        ],
        #number_of_slurm_nodes=NUMBER_OF_HOLDOUTS,
        enable_cache=True,
        number_of_holdouts=NUMBER_OF_HOLDOUTS,
        use_scale_free_distribution=validation_use_scale_free,
        validation_unbalance_rates=VALIDATION_UNBALANCE_RATES,
        subgraph_of_interest=subgraph,
        use_subgraph_as_support=True
    ))
results = pd.concat(results)
results.to_csv("kg_idg_negative_select.tsv",sep="\t")
# Out:
# Validation use scale free:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating on KGIDG:   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Validation use scale free:  50%|█████     | 1/2 [00:07<00:07,  7.71s/it]
# Evaluating on KGIDG:   0%|          | 0/10 [00:00<?, ?it/s]
# /Users/robinp/GIT/negativeExampleSelection/grape_env/lib/python3.8/site-packages/embiggen/edge_prediction/edge_prediction_model.py:144: UserWarning: Please do be advised that you have DISABLED the use of scale free sampling for the negative edges for the EVALUATION (not the training) of a model. This is a POOR CHOICE as it will introduce a positive bias as edges sampled uniformely have a significantly different node degree distribution than the positive edges in the graph, and are therefore much easier to predict. The only case where it makes sense to use this parameter is when evaluating how strongly this bias would have affected your task. DO NOT USE THIS CONFIGURATION IN ANY OTHER USE CASE.
#   warnings.warn(
#   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/robinp/GIT/negativeExampleSelection/grape_env/lib/python3.8/site-packages/embiggen/edge_prediction/edge_prediction_model.py:144: UserWarning: Please do be advised that you have DISABLED the use of scale free sampling for the negative edges for the EVALUATION (not the training) of a model. This is a POOR CHOICE as it will introduce a positive bias as edges sampled uniformely have a significantly different node degree distribution than the positive edges in the graph, and are therefore much easier to predict. The only case where it makes sense to use this parameter is when evaluating how strongly this bias would have affected your task. DO NOT USE THIS CONFIGURATION IN ANY OTHER USE CASE.
#   warnings.warn(
#   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/robinp/GIT/negativeExampleSelection/grape_env/lib/python3.8/site-packages/embiggen/edge_prediction/edge_prediction_model.py:144: UserWarning: Please do be advised that you have DISABLED the use of scale free sampling for the negative edges for the EVALUATION (not the training) of a model. This is a POOR CHOICE as it will introduce a positive bias as edges sampled uniformely have a significantly different node degree distribution than the positive edges in the graph, and are therefore much easier to predict. The only case where it makes sense to use this parameter is when evaluating how strongly this bias would have affected your task. DO NOT USE THIS CONFIGURATION IN ANY OTHER USE CASE.
#   warnings.warn(
#   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/robinp/GIT/negativeExampleSelection/grape_env/lib/python3.8/site-packages/embiggen/edge_prediction/edge_prediction_model.py:144: UserWarning: Please do be advised that you have DISABLED the use of scale free sampling for the negative edges for the EVALUATION (not the training) of a model. This is a POOR CHOICE as it will introduce a positive bias as edges sampled uniformely have a significantly different node degree distribution than the positive edges in the graph, and are therefore much easier to predict. The only case where it makes sense to use this parameter is when evaluating how strongly this bias would have affected your task. DO NOT USE THIS CONFIGURATION IN ANY OTHER USE CASE.
#   warnings.warn(
#   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/robinp/GIT/negativeExampleSelection/grape_env/lib/python3.8/site-packages/embiggen/edge_prediction/edge_prediction_model.py:144: UserWarning: Please do be advised that you have DISABLED the use of scale free sampling for the negative edges for the EVALUATION (not the training) of a model. This is a POOR CHOICE as it will introduce a positive bias as edges sampled uniformely have a significantly different node degree distribution than the positive edges in the graph, and are therefore much easier to predict. The only case where it makes sense to use this parameter is when evaluating how strongly this bias would have affected your task. DO NOT USE THIS CONFIGURATION IN ANY OTHER USE CASE.
#   warnings.warn(
#   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/robinp/GIT/negativeExampleSelection/grape_env/lib/python3.8/site-packages/embiggen/edge_prediction/edge_prediction_model.py:144: UserWarning: Please do be advised that you have DISABLED the use of scale free sampling for the negative edges for the EVALUATION (not the training) of a model. This is a POOR CHOICE as it will introduce a positive bias as edges sampled uniformely have a significantly different node degree distribution than the positive edges in the graph, and are therefore much easier to predict. The only case where it makes sense to use this parameter is when evaluating how strongly this bias would have affected your task. DO NOT USE THIS CONFIGURATION IN ANY OTHER USE CASE.
#   warnings.warn(
#   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/robinp/GIT/negativeExampleSelection/grape_env/lib/python3.8/site-packages/embiggen/edge_prediction/edge_prediction_model.py:144: UserWarning: Please do be advised that you have DISABLED the use of scale free sampling for the negative edges for the EVALUATION (not the training) of a model. This is a POOR CHOICE as it will introduce a positive bias as edges sampled uniformely have a significantly different node degree distribution than the positive edges in the graph, and are therefore much easier to predict. The only case where it makes sense to use this parameter is when evaluating how strongly this bias would have affected your task. DO NOT USE THIS CONFIGURATION IN ANY OTHER USE CASE.
#   warnings.warn(
#   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/robinp/GIT/negativeExampleSelection/grape_env/lib/python3.8/site-packages/embiggen/edge_prediction/edge_prediction_model.py:144: UserWarning: Please do be advised that you have DISABLED the use of scale free sampling for the negative edges for the EVALUATION (not the training) of a model. This is a POOR CHOICE as it will introduce a positive bias as edges sampled uniformely have a significantly different node degree distribution than the positive edges in the graph, and are therefore much easier to predict. The only case where it makes sense to use this parameter is when evaluating how strongly this bias would have affected your task. DO NOT USE THIS CONFIGURATION IN ANY OTHER USE CASE.
#   warnings.warn(
#   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/robinp/GIT/negativeExampleSelection/grape_env/lib/python3.8/site-packages/embiggen/edge_prediction/edge_prediction_model.py:144: UserWarning: Please do be advised that you have DISABLED the use of scale free sampling for the negative edges for the EVALUATION (not the training) of a model. This is a POOR CHOICE as it will introduce a positive bias as edges sampled uniformely have a significantly different node degree distribution than the positive edges in the graph, and are therefore much easier to predict. The only case where it makes sense to use this parameter is when evaluating how strongly this bias would have affected your task. DO NOT USE THIS CONFIGURATION IN ANY OTHER USE CASE.
#   warnings.warn(
#   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/robinp/GIT/negativeExampleSelection/grape_env/lib/python3.8/site-packages/embiggen/edge_prediction/edge_prediction_model.py:144: UserWarning: Please do be advised that you have DISABLED the use of scale free sampling for the negative edges for the EVALUATION (not the training) of a model. This is a POOR CHOICE as it will introduce a positive bias as edges sampled uniformely have a significantly different node degree distribution than the positive edges in the graph, and are therefore much easier to predict. The only case where it makes sense to use this parameter is when evaluating how strongly this bias would have affected your task. DO NOT USE THIS CONFIGURATION IN ANY OTHER USE CASE.
#   warnings.warn(
#   0%|          | 0/5 [00:00<?, ?it/s]
